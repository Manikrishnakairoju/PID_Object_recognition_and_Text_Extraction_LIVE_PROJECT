# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#   Using cached ultralytics-8.3.105-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# prompt: unzip new_annotate.zip

# !unzip /content/datasetNEW08_04_2025.zip
# Out:
# Archive:  /content/datasetNEW08_04_2025.zip
#    creating: new_annotate/
#    creating: new_annotate/train/
#    creating: new_annotate/train/images/
#   inflating: new_annotate/train/images/a1.jpg
#   inflating: new_annotate/train/images/a10.jpg
#   inflating: new_annotate/train/images/a2.jpg
#   inflating: new_annotate/train/images/a3.jpg
#   inflating: new_annotate/train/images/a4.jpg
#   inflating: new_annotate/train/images/a5.jpg
#   inflating: new_annotate/train/images/a6.jpg
#   inflating: new_annotate/train/images/a7.jpg
#   inflating: new_annotate/train/images/a8.jpg
#   inflating: new_annotate/train/images/a9.jpg
#   inflating: new_annotate/train/images/b.jpg
#   inflating: new_annotate/train/images/b1.jpg
#   inflating: new_annotate/train/images/b10.jpg
#   inflating: new_annotate/train/images/b2.jpg
#   inflating: new_annotate/train/images/b3.jpg
#   inflating: new_annotate/train/images/b4.jpg
#   inflating: new_annotate/train/images/b5.jpg
# ...

# %%
# Load pretrained model
model = YOLO('yolov8m.pt')

# %%
model.train(data="data.yaml",imgsz=640,batch=8,epochs=30,workers=0,device="0")
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
model= YOLO("yolov8best.pt")

# %%
model.predict(source="4.jpg",show=True,save=True)
results = model.predict('4.jpg', save=True)
results[0].show()  # Display detected circles
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/4.jpg: 640x480 40 circulars, 56.2ms
# Speed: 4.0ms preprocess, 56.2ms inference, 144.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
#
# image 1/1 /content/4.jpg: 640x480 40 circulars, 27.7ms
# Speed: 3.9ms preprocess, 27.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# <PIL.Image.Image image mode=RGB size=538x732>

# %%
# prompt: remove the detected items with confidence level lessthan 0.4

from ultralytics import YOLO

# Assuming the model and results are already defined as in your previous code

results = model.predict('4.jpg', save=True, conf=0.6) # Set confidence threshold to 0.4

# Now results only contains detections with confidence >= 0.4

results[0].show()  # Display detected circles (only those above the threshold)
# Out:
# image 1/1 /content/4.jpg: 640x480 33 circulars, 27.9ms
# Speed: 4.1ms preprocess, 27.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# <PIL.Image.Image image mode=RGB size=538x732>
